# %%
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.utils.data import download_file

# %%
# Dowload a sample 1D Quasar Spectrum from the SDSS/DESI public archives
url = "https://dr16.sdss.org/sas/dr16/sdss/spectro/redux/26/spectra/lite/0266/spec-0266-51602-0001.fits"

print("Downloading sample 1D spectrum...")
file_path = download_file(url, cache=True)

# %%
# Open The FITS file
with fits.open(file_path) as hdul:
    # HDU 1 contains the spectrum table (Wavelength, Flux)
    data = hdul[1].data
    flux = data['flux']
    # SDSS stores wavelength in log10(Angstroms)
    wavelength = 10 ** data['loglam']

# %%
# Plot the 1D Quasar Spectrum (Lyman-alpha Forest region)
plt.figure(figsize=(10, 4))
plt.plot(wavelength, flux, color='blue', lw=0.8)
plt.xlabel("Wavelength ($\AA$)")
plt.ylabel("Flux ($10^{-17}$ erg/cm$^2$/s/$\AA$)")
plt.title("1D Quasar Spectrum (Lyman-Alpha Line & Forest)")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
